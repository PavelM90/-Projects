# %% [markdown]
# # Train a YOLO model for soccer match related objects recognition

# %%
# Import libraries
from ultralytics import YOLO
import torch

# %%
# Connect google drive where the data is stored (Please note that this directory might change based on each user file path directions)
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# ## Get Image Recognition Data Set

# %% [markdown]
# ## Training

# %%
# Generate a training task using yaml file
# !yolo task=detect mode=train model=yolov5lu.pt data="/content/drive/MyDrive/Colab Notebooks/football-players-detection-10"/data.yaml epochs=100 imgsz=640 batch=4 verbose
# Out:
# ...
# 100% 102M/102M [00:00<00:00, 417MB/s]
# Ultralytics YOLOv8.2.66 🚀 Python-3.10.12 torch-2.3.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
# Save the best model to a goggle drive
# !cp /content/runs/detect/train/weights/best.pt "drive/MyDrive/Colab Notebooks/"

# %%
# Save the last mode to the google drive
# !cp /content/runs/detect/train/weights/last.pt "drive/MyDrive/Colab Notebooks/"
